# %% [markdown]
# ## Retrieval Reader Architecture

# %%
import datasets

# %%
from datasets import get_dataset_config_names

domains = get_dataset_config_names("subjqa")
domains
# Out:
# ['books', 'electronics', 'grocery', 'movies', 'restaurants', 'tripadvisor']

# %% [markdown]
# ### 1. Loading the dataset from datasets

# %%
from datasets import load_dataset

subjqa = load_dataset("subjqa" , name="electronics")

# %%
print(subjqa["train"]["answers"][3])
# Out:
# {'text': ['the best of all of them'], 'answer_start': [1609], 'answer_subj_level': [1], 'ans_subj_score': [0.30000001192092896], 'is_ans_subjective': [False]}

# %%
subjqa
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['domain', 'nn_mod', 'nn_asp', 'query_mod', 'query_asp', 'q_reviews_id', 'question_subj_level', 'ques_subj_score', 'is_ques_subjective', 'review_id', 'id', 'title', 'context', 'question', 'answers'],
#         num_rows: 1295
#     })
#     test: Dataset({
#         features: ['domain', 'nn_mod', 'nn_asp', 'query_mod', 'query_asp', 'q_reviews_id', 'question_subj_level', 'ques_subj_score', 'is_ques_subjective', 'review_id', 'id', 'title', 'context', 'question', 'answers'],
#         num_rows: 358
#     })
#     validation: Dataset({
#         features: ['domain', 'nn_mod', 'nn_asp', 'query_mod', 'query_asp', 'q_reviews_id', 'question_subj_level', 'ques_subj_score', 'is_ques_subjective', 'review_id', 'id', 'title', 'context', 'question', 'answers'],
#         num_rows: 255
#     })
# })

# %%
import pandas as pd

dfs = {split: dset.to_pandas() for split, dset in subjqa.flatten().items()}

for split, df in dfs.items():
    print(f"Number of questions in {split}: {df['id'].nunique()}")
# Out:
# Number of questions in train: 1295
# Number of questions in test: 358
# Number of questions in validation: 255

# %%
qa_cols = ["title", "question", "answers.text",
           "answers.answer_start", "context"]

sample_df = dfs["train"][qa_cols].sample(10, random_state=42)
sample_df.head(10)
# Out:
#            title                                      question  \
# 834   B005HMO6A6                 How do you like the keyboard?
# 327   B002C7481G                         How is the processor?
# 839   B005HMO6A6  Does this have the ability to use batteries?
# 1121  B009A5204K                    What is the sound quality?
# 976   B0075SUK14                              How is the zoom?
# 536   B003LR7ME6                     How do I get to the port?
# 477   B003ELYQGG                      How clear was the sound?
# 1078  B008ABOJKS              How do you like the performance?
# 889   B006W8U2MU             How did you like the performance?
# 76    B0002L5R78                What do you think about price?
#
#                                            answers.text answers.answer_start  \
# 834                                                  []                   []
# 327                                                  []                   []
# 839                                                  []                   []
# 1121                                                 []                   []
# 976                                                  []                   []
# 536                                                  []                   []
# 477   [Although the sound is nice and neutral, sound...              [0, 13]
# 1078  [the performance is excellent, I'd like to imp...          [225, 1989]
# 889                                                  []                   []
# 76                                                   []                   []
#
#                                                 context
# 834   The good*Overall design is elegant*Quality fee...
# 327   So I have had my iPad now for about a month. T...
# 839   -Love this product!  I have tried other wirele...
# 1121  One may look at me strangely, friends may call...
# 976   We just returned from a trip overseas and brou...
# 536   Love this case.  With the exception of the exp...
# 477   Although the sound is nice and neutral, the ba...
# 1078  asuswrt is by far the best firmware for this r...
# 889   This thing is so tiny it is hard to believe it...
# 76    So I ordered 3, and two work perfectly fine. O...

# %%
import matplotlib.pyplot as plt

counts = {}
question_types = ["What", "How", "Is", "Does", "Do", "Was", "Where", "Why"]

for q in question_types:
    counts[q] = dfs["train"]["question"].str.startswith(q).value_counts()[True]

pd.Series(counts).sort_values().plot.barh()
plt.title("Frequency of Question Types")
plt.show()

# %%
for question_type in ["How", "What", "Is"]:
    for question in (
        dfs["train"][dfs["train"].question.str.startswith(question_type)]
        .sample(n=3, random_state=10)['question']):
        print(question)
# Out:
# How was the signal?
# How is the connection of the cables?
# How was the power supply?
# What are the sizes of the lens?
# What is the performance of the product?
# What is earphone?
# Is the cable expensive?
# Is this phome comes with a charger?
# Is the bass sound the deepest ?

# %% [markdown]
# ### 2. Extracting Answers from Text

# %%
#Tokenizing text for Question Answering
from transformers import AutoTokenizer

model_ckpt = "deepset/minilm-uncased-squad2"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)

# %%
import torch 
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.8528, 0.4139, 0.8977],
#         [0.8279, 0.4856, 0.8436],
#         [0.8394, 0.0657, 0.8829],
#         [0.5054, 0.1242, 0.9699],
#         [0.7018, 0.5489, 0.3605]])

# %%
question = "How much music can this hold?"
context = """ An MP3 is about 1 MB/minute, so about 6000 hours depending on file size."""

inputs = tokenizer(question, context, return_tensors="pt")

# %%
# !huggingface-cli scan-cache
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# REPO ID                                          REPO TYPE SIZE ON DISK NB FILES LAST_ACCESSED LAST_MODIFIED REFS LOCAL PATH
# ------------------------------------------------ --------- ------------ -------- ------------- ------------- ---- ---------------------------------------------------------------------------------------------
# deepset/minilm-uncased-squad2                    model           232.2K        4 2 days ago    2 days ago    main /Users/oscar/.cache/huggingface/hub/models--deepset--minilm-uncased-squad2
# distilbert/distilbert-base-cased-distilled-squad model           261.4M        5 1 day ago     1 day ago     main /Users/oscar/.cache/huggingface/hub/models--distilbert--distilbert-base-cased-distilled-squad
#
# Done in 0.0s. Scanned 2 repo(s) for a total of 261.7M.
# Got 7 warning(s) while scanning. Use -vvv to print details.

# %%
print(tokenizer.decode(inputs["input_ids"][0]))
# Out:
# [CLS] how much music can this hold? [SEP] an mp3 is about 1 mb / minute, so about 6000 hours depending on file size. [SEP]

# %%
import torch

from transformers import AutoModelForQuestionAnswering

model = AutoModelForQuestionAnswering.from_pretrained(model_ckpt)

with torch.no_grad():
    outputs = model(**inputs)

print(outputs)
# Out:
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# Some weights of the model checkpoint at deepset/minilm-uncased-squad2 were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# QuestionAnsweringModelOutput(loss=None, start_logits=tensor([[-0.9862, -4.7750, -5.4025, -5.2378, -5.2863, -5.5117, -4.9819, -6.1880,
#          -0.9862,  0.2596, -0.2144, -1.7136,  3.7806,  4.8561, -1.0546, -3.9097,
#          -1.7374, -4.5944, -1.4278,  3.9949,  5.0391, -0.2018, -3.0193, -4.8549,
#          -2.3108, -3.5110, -3.5713, -0.9862]]), end_logits=tensor([[-0.9623, -5.4733, -5.0326, -5.1639, -5.4278, -5.5151, -5.1749, -4.6233,
#          -0.9623, -3.7855, -0.8715, -3.7745, -3.0161, -1.1780,  0.1758, -2.7365,
#           4.8934,  0.3046, -3.1761, -3.2762,  0.8937,  5.6606, -0.3623, -4.9554,
#          -3.2531, -0.0914,  1.6211, -0.9623]]), hidden_states=None, attentions=None)

# %%
start_logits = outputs.start_logits
end_logits = outputs.end_logits

# %%
print(f"Inputs IDs shape: {inputs.input_ids.size()}")
print(f"Start logits shape: {start_logits.size()}")
print(f"End logits shape: {end_logits.size()}")
# Out:
# Inputs IDs shape: torch.Size([1, 28])
# Start logits shape: torch.Size([1, 28])
# End logits shape: torch.Size([1, 28])

# %%
import torch

start_idx = torch.argmax(start_logits)
end_idx = torch.argmax(end_logits) + 1
answer_span = inputs["input_ids"][0][start_idx:end_idx]
answer = tokenizer.decode(answer_span)

print(f"Question: {question}")
print(f"Answer: {answer}")
# Out:
# Question: How much music can this hold?
# Answer: 6000 hours

# %%
from transformers import pipeline

pipe = pipeline("question-answering", model=model, tokenizer=tokenizer)
pipe(question=question, context=context, topk=3)
# Out:
# /Users/oscar/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/transformers/pipelines/question_answering.py:326: UserWarning: topk parameter is deprecated, use top_k instead
#   warnings.warn("topk parameter is deprecated, use top_k instead", UserWarning)
# [{'score': 0.2651623785495758, 'start': 39, 'end': 49, 'answer': '6000 hours'},
#  {'score': 0.22082938253879547,
#   'start': 17,
#   'end': 49,
#   'answer': '1 MB/minute, so about 6000 hours'},
#  {'score': 0.10253461450338364,
#   'start': 17,
#   'end': 28,
#   'answer': '1 MB/minute'}]

# %%
pipe(question = "Why is there no data?", context=context, 
    handle_impossible_answer=True)
# Out:
# {'score': 0.9068410992622375, 'start': 0, 'end': 0, 'answer': ''}

# %% [markdown]
# ### Dealing with long passages

# %%
example = dfs["train"].iloc[0][["question", "context"]]

tokenized_example = tokenizer(example["question"], example["context"],
                              return_overflowing_tokens=True, max_length=100,
                              stride=25)

# %%
for idx , window in enumerate(tokenized_example["input_ids"]):
    print(f"{tokenizer.decode(window)} \n")
# Out:
# [CLS] how is the bass? [SEP] i have had koss headphones in the past, pro 4aa and qz - 99. the koss portapro is portable and has great bass response. the work great with my android phone and can be " rolled up " to be carried in my motorcycle jacket or computer bag without getting crunched. they are very light and do not feel heavy or bear down on your ears even after listening to music with them on all day. the sound is [SEP]
#
# [CLS] how is the bass? [SEP] and do not feel heavy or bear down on your ears even after listening to music with them on all day. the sound is night and day better than any ear - bud could be and are almost as good as the pro 4aa. they are " open air " headphones so you cannot match the bass to the sealed types, but it comes close. for $ 32, you cannot go wrong. [SEP]

# %%
for window in tokenized_example["input_ids"]:
    print(f"{tokenizer.decode(window)} \n")
# Out:
# [CLS] how is the bass? [SEP] i have had koss headphones in the past, pro 4aa and qz - 99. the koss portapro is portable and has great bass response. the work great with my android phone and can be " rolled up " to be carried in my motorcycle jacket or computer bag without getting crunched. they are very light and do not feel heavy or bear down on your ears even after listening to music with them on all day. the sound is [SEP]
#
# [CLS] how is the bass? [SEP] and do not feel heavy or bear down on your ears even after listening to music with them on all day. the sound is night and day better than any ear - bud could be and are almost as good as the pro 4aa. they are " open air " headphones so you cannot match the bass to the sealed types, but it comes close. for $ 32, you cannot go wrong. [SEP]

# %% [markdown]
# ### Using Haystack to Bulid a QA Pipeline

# %% [markdown]
# ### Retriever Reader Architecture

# %%
# !ls -la
# Out:
# total 625976
# drwxr-xr-x@  9 macbook  staff        288 Mar 15 14:08 .
# drwxr-xr-x@ 22 macbook  staff        704 Mar 15 14:08 ..
# drwxr-xr-x@ 12 macbook  staff        384 Mar 15 14:08 .git
# drwxr-xr-x@  3 macbook  staff         96 Mar 12 11:01 .ipynb_checkpoints
# -rw-r--r--   1 macbook  staff         14 Mar 11 22:31 README.md
# -rw-r--r--   1 macbook  staff      59906 Mar 16 11:24 Retriever_Reader_QA_System.ipynb
# drwxr-xr-x@ 13 macbook  staff        416 Mar 15 14:08 elasticsearch-7.17.18
# -rw-r--r--   1 macbook  staff  320426531 Feb  6 12:36 elasticsearch-7.17.18-darwin-x86_64.tar.gz
# -rw-r--r--   1 macbook  staff        173 Feb  6 12:37 elasticsearch-7.17.18-darwin-x86_64.tar.gz.sha512

# %%
import os 
from subprocess import Popen, PIPE , STDOUT

# Run ElasticSearch as a backgroung process 
# !chown -R daemon:daemon elasticsearch-7.17.18
es_server = Popen(args=['elasticsearch-7.17.18/bin/elasticsearch'],
                  stdout=PIPE, stder=STDOUT, preexec_fn=lambda: os.setuid(1))

# wait until Elasticsearch has started
# !sleep 30
# Out:
# chown: elasticsearch-7.17.18/bin/elasticsearch-syskeygen: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-env: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-geoip: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-env-from-file: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-node: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-saml-metadata: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-keystore: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-plugin: Operation not permitted
# chown: elasticsearch-7.17.18/bin/x-pack-env: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-sql-cli: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-shard: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-setup-passwords: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-sql-cli-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-migrate: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-croneval: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-certgen: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-certutil: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-users: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-cli: Operation not permitted
# chown: elasticsearch-7.17.18/bin/x-pack-security-env: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch: Operation not permitted
# chown: elasticsearch-7.17.18/bin/elasticsearch-service-tokens: Operation not permitted
# chown: elasticsearch-7.17.18/bin/x-pack-watcher-env: Operation not permitted
# chown: elasticsearch-7.17.18/bin: Operation not permitted
# chown: elasticsearch-7.17.18/config/jvm.options.d: Operation not permitted
# chown: elasticsearch-7.17.18/config/users_roles: Operation not permitted
# chown: elasticsearch-7.17.18/config/role_mapping.yml: Operation not permitted
# chown: elasticsearch-7.17.18/config/users: Operation not permitted
# chown: elasticsearch-7.17.18/config/elasticsearch.yml: Operation not permitted
# chown: elasticsearch-7.17.18/config/elasticsearch.keystore: Operation not permitted
# chown: elasticsearch-7.17.18/config/roles.yml: Operation not permitted
# chown: elasticsearch-7.17.18/config/log4j2.properties: Operation not permitted
# chown: elasticsearch-7.17.18/config/elasticsearch-plugins.example.yml: Operation not permitted
# chown: elasticsearch-7.17.18/config/jvm.options: Operation not permitted
# chown: elasticsearch-7.17.18/config: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/CodeResources: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/_CodeSignature/CodeResources: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/_CodeSignature/CodeDirectory: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/_CodeSignature/CodeRequirements-1: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/_CodeSignature/CodeSignature: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/_CodeSignature/CodeRequirements: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/_CodeSignature: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jwebserver: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jarsigner: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jfr: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jdb: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jstack: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/rmiregistry: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jar: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jcmd: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jrunscript: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jps: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/java: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jhsdb: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/javap: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jdeprscan: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/javac: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/keytool: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jmod: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jmap: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jshell: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jstat: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jlink: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/serialver: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/javadoc: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jinfo: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jstatd: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jdeps: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jconsole: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jpackage: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin/jimage: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/bin: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include/jawt.h: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include/classfile_constants.h: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include/jdwpTransport.h: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include/jvmti.h: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include/jni.h: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include/jvmticmlr.h: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include/darwin/jni_md.h: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include/darwin/jawt_md.h: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include/darwin: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/include: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/release: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libnet.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libnio.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libinstrument.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libzip.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/psfontj2d.properties: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/fontconfig.properties.src: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libfreetype.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libjli.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libsplashscreen.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libmanagement_ext.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libdt_socket.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libj2pkcs11.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/jvm.cfg: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libjimage.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/security/public_suffix_list.dat: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/security/default.policy: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/security/cacerts: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/security/blocked.certs: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/security: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/jfr/default.jfc: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/jfr/profile.jfc: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/jfr: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/shaders.metallib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libosxkrb5.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/lible.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libosxui.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/tzdb.dat: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libmanagement_agent.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/librmi.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libjdwp.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libawt_lwawt.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/server/classes_nocoops.jsa: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/server/libjvm.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/server/classes.jsa: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/server/libjsig.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/server: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libjavajpeg.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libmlib_image.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libmanagement.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libjsound.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/ct.sym: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libj2pcsc.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libjsig.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libprefs.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libsyslookup.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libjawt.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libattach.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/jrt-fs.jar: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libfontmanager.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/fontconfig.bfc: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/jspawnhelper: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libosxsecurity.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libextnet.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libjaas.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/liblcms.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libverify.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/psfont.properties.ja: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libj2gss.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libsaproc.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/modules: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/classlist: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libjava.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libawt.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libosx.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib/libosxapp.dylib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/lib: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.management.rmi/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.management.rmi/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.management.rmi/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.management.rmi: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.unsupported.desktop/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.unsupported.desktop/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.unsupported.desktop/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.unsupported.desktop: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.compiler.management/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.compiler.management/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.compiler.management/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.compiler.management: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.se/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.se/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.se/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.se: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.security.jgss/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.security.jgss/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.security.jgss/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.security.jgss: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jfr/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jfr/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jfr/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jfr: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.management/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.management/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.management/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.management: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.security.sasl/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.security.sasl/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.security.sasl/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.security.sasl: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.net/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.net/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.net/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.net: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jsobject/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jsobject/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jsobject/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jsobject: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.zipfs/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.zipfs/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.zipfs/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.zipfs: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.incubator.vector/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.incubator.vector/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.incubator.vector/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.incubator.vector: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.dynalink/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.dynalink/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.dynalink/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.dynalink/dynalink.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.dynalink: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.compiler/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.compiler/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.compiler/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.compiler: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml/bcel.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml/xalan.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml/dom.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml/jcup.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml/xerces.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jcmd/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jcmd/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jcmd/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jcmd: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.naming.dns/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.naming.dns/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.naming.dns/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.naming.dns: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.instrument/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.instrument/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.instrument/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.instrument: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.localedata/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.localedata/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.localedata/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.localedata/cldr.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.localedata/thaidict.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.localedata: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.naming.rmi/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.naming.rmi/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.naming.rmi/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.naming.rmi: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.compiler/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.compiler/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.compiler/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.compiler: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.prefs/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.prefs/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.prefs/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.prefs: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.cryptoki/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.cryptoki/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.cryptoki/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.cryptoki/pkcs11wrapper.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.cryptoki/pkcs11cryptotoken.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.cryptoki: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.editpad/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.editpad/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.editpad/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.editpad: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.logging/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.logging/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.logging/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.logging: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.compiler/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.compiler/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.compiler/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.compiler: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/asm.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/public_suffix.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/cldr.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/icu.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/unicode.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/c-libutl.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base/aes.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.base: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.net.http/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.net.http/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.net.http/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.net.http: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jpackage/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jpackage/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jpackage/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jpackage: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.opt/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.opt/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.opt/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.opt/jopt-simple.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.opt: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jconsole/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jconsole/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jconsole/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jconsole: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.sql.rowset/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.sql.rowset/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.sql.rowset/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.sql.rowset: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.security.jgss/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.security.jgss/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.security.jgss/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.security.jgss: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.httpserver/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.httpserver/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.httpserver/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.httpserver: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.naming/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.naming/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.naming/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.naming: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.jvmstat/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.jvmstat/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.jvmstat/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.jvmstat: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jartool/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jartool/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jartool/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jartool: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.unsupported/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.unsupported/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.unsupported/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.unsupported: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdwp.agent/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdwp.agent/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdwp.agent/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdwp.agent: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.le/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.le/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.le/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.le/jline.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.le: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.ed/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.ed/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.ed/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.ed: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.scripting/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.scripting/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.scripting/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.scripting: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.attach/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.attach/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.attach/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.attach: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.security.auth/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.security.auth/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.security.auth/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.security.auth: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.xml.dom/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.xml.dom/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.xml.dom/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.xml.dom: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.charsets/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.charsets/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.charsets/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.charsets: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.sctp/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.sctp/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.sctp/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.sctp: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.rmi/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.rmi/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.rmi/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.rmi: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.smartcardio/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.smartcardio/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.smartcardio/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.smartcardio/pcsclite.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.smartcardio: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jstatd/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jstatd/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jstatd/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jstatd: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.transaction.xa/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.transaction.xa/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.transaction.xa/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.transaction.xa: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.hotspot.agent/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.hotspot.agent/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.hotspot.agent/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.hotspot.agent: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdi/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdi/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdi/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdi: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.javadoc/jquery.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.javadoc/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.javadoc/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.javadoc/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.javadoc/jqueryUI.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.javadoc: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jlink/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jlink/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jlink/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jlink: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.nio.mapmode/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.nio.mapmode/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.nio.mapmode/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.nio.mapmode: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.sql/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.sql/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.sql/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.sql: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management.jfr/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management.jfr/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management.jfr/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management.jfr: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.accessibility/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.accessibility/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.accessibility/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.accessibility: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.datatransfer/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.datatransfer/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.datatransfer/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.datatransfer: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jshell/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jshell/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jshell/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jshell: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdeps/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdeps/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdeps/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.jdeps: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/freetype.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/mesa3d.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/colorimaging.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/libpng.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/xwd.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/giflib.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/harfbuzz.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/jpeg.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/pipewire.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop/lcms.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.desktop: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.random/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.random/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.random/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.random: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.ec/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.ec/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.ec/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.crypto.ec: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management.agent/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management.agent/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management.agent/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.management.agent: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml.crypto/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml.crypto/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml.crypto/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml.crypto/santuario.md: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/java.xml.crypto: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.ci/LICENSE: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.ci/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.ci/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal/jdk.internal.vm.ci: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/legal: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/conf/logging.properties: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/conf/sound.properties: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/conf/security/java.security: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/conf/security/java.policy: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/conf/security/policy/unlimited/default_US_export.policy: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/conf/security/policy/unlimited/default_local.policy: Operation not permitted
# chown: elasticsearch-7.17.18/jdk.app/Contents/Home/conf/security/policy/unlimited: Operation not permitted
# ...
# chown: elasticsearch-7.17.18/modules/x-pack-enrich/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-enrich: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-fleet/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-fleet/x-pack-fleet-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-fleet/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-fleet/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-fleet: Operation not permitted
# chown: elasticsearch-7.17.18/modules/transform/transform-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/transform/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/transform/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/transform/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/transform: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-analytics/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-analytics/commons-math3-3.6.1.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-analytics/x-pack-analytics-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-analytics/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-analytics/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-analytics/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-analytics: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ilm/x-pack-ilm-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ilm/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ilm/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ilm/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ilm: Operation not permitted
# chown: elasticsearch-7.17.18/modules/ingest-user-agent/ingest-user-agent-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/ingest-user-agent/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/ingest-user-agent: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-sql/sql-proto-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-sql/aggs-matrix-stats-client-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-sql/sql-action-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-sql/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-sql/x-pack-sql-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-sql/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-sql/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-sql/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-sql: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-stack/x-pack-stack-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-stack/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-stack/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-stack/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-stack: Operation not permitted
# chown: elasticsearch-7.17.18/modules/aggs-matrix-stats/aggs-matrix-stats-client-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/aggs-matrix-stats/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/aggs-matrix-stats: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ccr/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ccr/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ccr/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ccr/x-pack-ccr-7.17.18.jar: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ccr/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.17.18/modules/x-pack-ccr: Operation not permitted
# chown: elasticsearch-7.17.18/modules: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/segments_1w: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/manifest-1.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/_1p.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/node-1.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/_1o.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/_1o.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/_1p.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/_1p.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/write.lock: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state/_1o.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/_state: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/node.lock: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/_state/state-8.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/_state: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/_state/retention-leases-2.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/_state/state-1.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/_state: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/translog/translog.ckp: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/translog/translog-4.tlog: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/translog: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/index/_0.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/index/_0.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/index/segments_3: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/index/_0.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/index/write.lock: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0/index: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q/0: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/ToGBKKs3SaSoNag4HP174Q: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/_state/state-7.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/_state: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/_state/retention-leases-2.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/_state/state-1.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/_state: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/translog/translog.ckp: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/translog/translog-4.tlog: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/translog: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/index/_0.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/index/_1.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/index/_0.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/index/_1.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/index/segments_3: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/index/_0.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/index/_1.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/index/write.lock: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0/index: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ/0: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/GmMjn2pITlO4vj-7W1LQzQ: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/_state/state-4.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/_state: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/_state/retention-leases-2.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/_state/state-1.st: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/_state: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/translog/translog.ckp: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/translog/translog-5.tlog: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/translog: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_f.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_g.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c.fnm: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c.fdx: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c_Lucene80_0.dvd: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c_Lucene80_0.dvm: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_e.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_d.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c.fdm: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_g.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_6.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_f.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/segments_4: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_b.cfe: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_b.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c.kdd: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c.kdm: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_f.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c.fdt: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_g.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_e.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_d.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_6.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c_Lucene84_0.tmd: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_b.cfs: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c_Lucene84_0.tip: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c.kdi: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/write.lock: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_e.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_6.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c_Lucene84_0.tim: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_c_Lucene84_0.doc: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index/_d.si: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0/index: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA/0: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices/51YT98oxRve9gysEb0mNOA: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/indices: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/snapshot_cache/segments_2: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/snapshot_cache/write.lock: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0/snapshot_cache: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes/0: Operation not permitted
# chown: elasticsearch-7.17.18/data/nodes: Operation not permitted
# chown: elasticsearch-7.17.18/data: Operation not permitted
# chown: elasticsearch-7.17.18: Operation not permitted
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 6
#       4 # Run ElasticSearch as a backgroung process
#       5 get_ipython().system('chown -R daemon:daemon elasticsearch-7.17.18')
# ----> 6 es_server = Popen(args=['elasticsearch-7.17.18/bin/elasticsearch'],
#       7                   stdout=PIPE, stder=STDOUT, preexec_fn=lambda: os.setuid(1))
#       9 # wait until Elasticsearch has started
#      10 get_ipython().system('sleep 30')
#
# TypeError: __init__() got an unexpected keyword argument 'stder'

# %%
# !curl -X GET "localhost:9200/?pretty"
# Out:
# curl: (7) Failed to connect to localhost port 9200 after 0 ms: Connection refused

# %%
from haystack.document_store.elasticsearch import ElasticsearchDocumentStore

# return the document embedding for later use with the dense retriver
document_store = ElasticsearchDocument(return_embedding=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from haystack.document_store.elasticsearch import ElasticsearchDocumentStore
#       3 # return the document embedding for later use with the dense retriver
#       4 document_store = ElasticsearchDocument(return_embedding=True)
#
# ModuleNotFoundError: No module named 'haystack'

# %%
for split ,df in dfs.items():
    #Exclude duplicate reviews 
    docs = [{"text": row["context"],
             "meta":{"item_id": row["title"], "question_id": row["id"],
                     "split": split}}
            for _, row in df.drop_duplicates(subset="context").iterrows()]
    document_store.write_documents(docs, index="document")

print(f"Loaded {document_store.get_document_count()} documents")

# %%
# initializing a retriever
from haystack.retriever.sparse import ElasticsearchRetriever

es_retriever = ElasticsearchRetriever(document_store=document_store)

# %%
# test 1 
item_id = "B0074BW614"
query = "Is it good for reading?"
retrieved_docs = es_retriever.retrieve(
    query=query, top_k=3, filters={"item_id":[item_id], "split": ["train"]})

# %%
print(retrieved_docs[0])

# %%
# initailizing the reader
from haystack.reader.farm import FARMReader

model_ckpt = "deepset/minlm-uncased-squad2"
max_seq_length, doc_stride = 384, 128
reader = FARMReader(model_name_or_path=model_ckpt, progress_bar=False, 
                    max_seq_len=max_seq_length, doc_stride=doc_stride,
                    return_no_answer=True)

# %%
print(reader.predict_on_tests(question=question, texts=[context], top_k=1))

# %%
# putting it all together

from haystack.pipeline import ExtractveQAPipeline

pipe = ExtractiveQAPipeline(reader, es_retriever)

# %%
n_answers = 3
preds = pipe.run(query=query, top_k_retriever=3, top_k_reader=n_answers,
                 filters={"item_id": [item_id], "split": ["train"]})

print(f"Question: {preds['query']}\n")

# %%
for idx in range(n_answers):
    print(f"Answer {idx+1}: {preds['answers'][idx]['answer']}")
    print(f"Review snippet: ... {preds['answers'][idx]['context']}...")\
    print("\n\n")
# Out:
#   Cell In[7], line 1
#     for idx in range(n_answers):
#                                 ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### improving the QA pipeline

# %%
class PipelineNode:
    def __init__(self):
        self.outgoing_edges = 1

    def run(self, **kwargs):
        return outputs, "outgoing_edge_name")
# Out:
#   Cell In[2], line 5
#     def rn(self, **kwargs):
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
from haystack.pipeline import Pipeline
from haystack.eval import EvalDocuments

class EvalRetrieverPipeline:
    def __init__(self, retriever):
        self.retriever = retriever
        self.eval_retriever = EvalDocuments()
        pipe = Pipeline()
        pipe.add_node(components=self.retriever, name="ESRetriever",
                     inputs = ["Query"])
        pipe.add_node(components=self.eval_retriever, name="EvalRetriever",
                      inputs=["ESRetriever"])
        self.pipeline = pipe

pipe = EvalRetrieverPipeline(es_retriever)

# %%
from haystack import Label 

labels = []

for i , rows in dfs["test"].iterrows():
    meta = {"item_id": row["title"], "question_id": row["id"]}
    if len(row["answers.text"]):  
        for answer in rows["answers.text"]:     
            label = Label(
                question = row["question"], answer=answer, id=i, origin=row["id"],
                meta=meta, is_correct=True, is_correct_document=True, no_aswer=False)
                labels.append(label)
    else:
        label = Label(
            question = row["question"], answer=answer, id=i, origin=row["id"],
            meta=meta, is_correct=True, is_correct_document=True, no_aswer=False)
            labels.append(label)
# Out:
#   Cell In[3], line 5
#     for i , rows in dfs["test].iterrows():
#                                           ^
# SyntaxError: EOL while scanning string literal

# %%
print(labels[0])

# %%
document_store.write_labels(labels, index="label")
print(f"""Loaded {document_store.get_label_count(index="label")} \ 
question-answering pairs""")

# %%
labels_agg = document_store.get_all_labels_aggregated(
    index="label",
    open_domain=True,
    aggregate_by_meta=["item_id"])

print(len(labels_agg))

# %% [markdown]
# ### Retrieval Augmented Generation Model 1

# %%
from haystack.generator.transformers import RAGenerator

generator = RAGenerator(model_name_or_path="facebook/rag-token-nq",
                        embed_title=False, num_beams=5)

# %%
from haystack.pipeline import GenerativeQAPipeline

pipe = GenerativeQAPipeline(generator=generator, retriever=dpr_retriever)

# %%
def generate_answers(query, top_k_generator=3):
    preds = pipe.run(query=query, top_k_generator=top_k_generator,
                     top_k_retriever=5, filters={"items_id": ["B0074BW614"]})
    print(f"Question: {preds['query']} \n")
    for idx in range(top_k_generator):
        print(f"Answer {idx+1}: {preds['answer'][idx]['answer']}")
# Out:
#   Cell In[34], line 1
#     def generate_answers(query, top_k_generator=3):
#                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
generate_answers(query)

# %%
generate_answers("What is the main drawbacks?")
